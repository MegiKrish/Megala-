# %% [markdown]
# ## Pandas Assignment 4

# %%
import pandas as pd

# %%
cust=pd.read_csv('C:\\Users\\megik\\Downloads\\customer_churn-1.csv')

# %%
cust
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# #### 1.Sort the data by the tenure column according to descending order

# %%
cust.sort_values(by='tenure', ascending=False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# ...

# %% [markdown]
# ### 2.Fetch all the records with following condition

# %% [markdown]
# #### a.tenure > 50 and the gender as 'female'.

# %%
cust.iloc[:,[1]]='Female'

# %%
cust.loc[cust['tenure']>50]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU  Female              0      No        Yes      62
# 12    8091-TTVAX  Female              0     Yes         No      58
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 17    9959-WOFKT  Female              0      No        Yes      71
# ...          ...     ...            ...     ...        ...     ...
# 7031  3605-JISKB  Female              1     Yes         No      55
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK  Female              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 9             Yes            No             DSL                  Yes  ...
# ...

# %% [markdown]
# #### b.Gender as male and senior citizen as 0

# %%
cust.iloc[:,[1]]='Male'

# %%
cust.iloc[:,[2]]=0

# %%
cust
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG   Male              0     Yes         No       1
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 4     9237-HQITU   Male              0      No         No       2
# ...          ...    ...            ...     ...        ...     ...
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7039  2234-XADUH   Male              0     Yes        Yes      72
# 7040  4801-JZAZL   Male              0     Yes        Yes      11
# 7041  8361-LTMKD   Male              0     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# #### c.Tech support as 'yes' and Churn as 'No'

# %%
cust.iloc[:,[12]]='Yes'

# %%
cust.iloc[:,[20]]='No'

# %%
cust
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# #### d.Contract type as 'Month-to-month' and Churn as 'No'

# %%
cust.iloc[:,[15]]='Month-to-month'

# %%
cust.iloc[:,[20]]='Yes'

# %%
cust
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...
