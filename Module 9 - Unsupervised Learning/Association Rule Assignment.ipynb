# %% [markdown]
# ## Association Rule Assignment

# %%
! pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=1ee6bfd1a2502eabe2295f3b2bfd99cbe43fd271bf279f8ecd59f10f76ae19ea
#   Stored in directory: c:\users\megik\appdata\local\pip\cache\wheels\32\2a\54\10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %% [markdown]
# Using pandas import the dataset as dataframe.|

# %%
pwd
# Out:
# 'C:\\Users\\megik'

# %%
df=pd.read_csv('C:\\Users\\megik\\downloads\\Retail.csv')

# %%
df.head()
# Out:
#                                              Column1  Column2       Column3  \
# 0                     Transactions from the Database      NaN           NaN
# 1      1 : { Pencils, Markers, Highlighters, Papers}      NaN       Pencils
# 2                             2 : {Markers, Erasers}      NaN       Markers
# 3  3 : {Stapler Pins, Papers, Erasers, Card Holde...      NaN  Highlighters
# 4                 4 : {Papers, Erasers, Cad Holders}      NaN        Papers
#
#                                        Column4  Column5 Column6
# 0  #Transactions in which\n the item is bought  Support     NaN
# 1                                            2      0.2     NaN
# 2                                            6      0.6     NaN
# 3                                            3      0.3     NaN
# 4                                            4      0.4     NaN

# %% [markdown]
# Install the mixtend library to use apriory and association rule mining.

# %%
#converting dataframe into list of lists
l=[]
for i in range(1,17):
    l.append([str(df.values[i,j]) for j in range(0,6)])

# %%
#applying apriori algorithm
association_rules = apriori(l, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %% [markdown]
# Using the apriori algorithm generate a list of item frequently brought together.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'Construct item-sets with items that satisfy minimum support', '#Transactions in which\n the item is bought'})
# frozenset({'#Transactions in which\n the item is bought', 'Support\nP(MarkersÇErasers)'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', '0.2'})
# frozenset({'2', '0.2'})
# frozenset({'7 : {Markers, Erasers}', '0.2'})
# frozenset({'0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'Card Holders', '0.2'})
# frozenset({'Envelop', '0.2'})
# frozenset({'Pencils', '0.2'})
# frozenset({'3', '0.3'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', '0.3'})
# frozenset({'6 : {Envelop}', '0.3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '0.3'})
# frozenset({'Highlighters', '0.3'})
# frozenset({'0.3', 'Post-it'})
# frozenset({'Stapler Pins', '0.3'})
# frozenset({'4', '0.4'})
# frozenset({'4 : {Papers, Erasers, Cad Holders}', '0.4'})
# frozenset({'Papers', '0.4'})
# frozenset({'5', '0.5'})
# frozenset({'Markers,Erasers', '0.5'})
# frozenset({'2 : {Markers, Erasers}', '0.6'})
# frozenset({'6', '0.6'})
# frozenset({'Markers', '0.6'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '0.7'})
# frozenset({'7', '0.7'})
# frozenset({'0.7', 'Erasers'})
# frozenset({'1.19', '0.833'})
# frozenset({'RULE: Markers = > Erasers', '0.833'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', '2'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils'})
# frozenset({'RULE: Markers = > Erasers', '1.19'})
# frozenset({'7 : {Markers, Erasers}', '2'})
# frozenset({'2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'Card Holders', '2'})
# frozenset({'Envelop', '2'})
# frozenset({'Pencils', '2'})
# frozenset({'2 : {Markers, Erasers}', '6'})
# frozenset({'2 : {Markers, Erasers}', 'Markers'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', '3'})
# frozenset({'6 : {Envelop}', '3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '3'})
# frozenset({'3', 'Highlighters'})
# frozenset({'3', 'Post-it'})
# frozenset({'3', 'Stapler Pins'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'Highlighters'})
# frozenset({'4', '4 : {Papers, Erasers, Cad Holders}'})
# frozenset({'4', 'Papers'})
# frozenset({'4 : {Papers, Erasers, Cad Holders}', 'Papers'})
# frozenset({'5', 'Markers,Erasers'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7'})
# frozenset({'5 : {Markers, Post-it, Erasers}', 'Erasers'})
# frozenset({'6', 'Markers'})
# frozenset({'6 : {Envelop}', 'Stapler Pins'})
# frozenset({'7', 'Erasers'})
# frozenset({'7 : {Markers, Erasers}', 'Card Holders'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'Post-it'})
# frozenset({'Envelop', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'Lift\nP(Erasers|Markers) / P( Erasers)', 'Confidence\n P(Erasers|Markers) = P(MarkersÇErasers)/P(Markers)'})
# frozenset({'Construct item-sets with items that satisfy minimum support', 'Support\nP(MarkersÇErasers)'})
# frozenset({'Construct item-sets with items that satisfy minimum support', '#Transactions in which\n the item is bought', 'Support\nP(MarkersÇErasers)'})
# frozenset({'Construct item-sets with items that satisfy minimum support', 'nan', '#Transactions in which\n the item is bought'})
# frozenset({'nan', '#Transactions in which\n the item is bought', 'Support\nP(MarkersÇErasers)'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', '2', '0.2'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils', '0.2'})
# frozenset({'nan', '1 : { Pencils, Markers, Highlighters, Papers}', '0.2'})
# frozenset({'7 : {Markers, Erasers}', '2', '0.2'})
# frozenset({'2', '0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'Card Holders', '2', '0.2'})
# frozenset({'Envelop', '2', '0.2'})
# frozenset({'Pencils', '2', '0.2'})
# frozenset({'nan', '2', '0.2'})
# frozenset({'7 : {Markers, Erasers}', 'Card Holders', '0.2'})
# frozenset({'7 : {Markers, Erasers}', 'nan', '0.2'})
# frozenset({'Envelop', '0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', '0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', 'Card Holders', '0.2'})
# frozenset({'nan', 'Envelop', '0.2'})
# frozenset({'nan', 'Pencils', '0.2'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', '3', '0.3'})
# frozenset({'6 : {Envelop}', '3', '0.3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '3', '0.3'})
# frozenset({'Highlighters', '3', '0.3'})
# frozenset({'3', '0.3', 'Post-it'})
# frozenset({'3', '0.3', 'Stapler Pins'})
# frozenset({'nan', '3', '0.3'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'Highlighters', '0.3'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'nan', '0.3'})
# frozenset({'6 : {Envelop}', 'Stapler Pins', '0.3'})
# frozenset({'6 : {Envelop}', 'nan', '0.3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '0.3', 'Post-it'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'nan', '0.3'})
# frozenset({'Highlighters', 'nan', '0.3'})
# frozenset({'nan', '0.3', 'Post-it'})
# frozenset({'nan', 'Stapler Pins', '0.3'})
# frozenset({'4', '4 : {Papers, Erasers, Cad Holders}', '0.4'})
# frozenset({'4', '0.4', 'Papers'})
# frozenset({'4', 'nan', '0.4'})
# frozenset({'4 : {Papers, Erasers, Cad Holders}', '0.4', 'Papers'})
# frozenset({'4 : {Papers, Erasers, Cad Holders}', 'nan', '0.4'})
# frozenset({'Papers', 'nan', '0.4'})
# frozenset({'5', '0.5', 'Markers,Erasers'})
# frozenset({'nan', '5', '0.5'})
# frozenset({'nan', 'Markers,Erasers', '0.5'})
# frozenset({'2 : {Markers, Erasers}', '6', '0.6'})
# frozenset({'2 : {Markers, Erasers}', 'Markers', '0.6'})
# frozenset({'2 : {Markers, Erasers}', 'nan', '0.6'})
# frozenset({'Markers', '6', '0.6'})
# frozenset({'6', 'nan', '0.6'})
# frozenset({'Markers', 'nan', '0.6'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7', '0.7'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '0.7', 'Erasers'})
# frozenset({'5 : {Markers, Post-it, Erasers}', 'nan', '0.7'})
# frozenset({'7', '0.7', 'Erasers'})
# frozenset({'7', '0.7', 'nan'})
# frozenset({'nan', '0.7', 'Erasers'})
# frozenset({'RULE: Markers = > Erasers', '1.19', '0.833'})
# frozenset({'nan', '1.19', '0.833'})
# frozenset({'RULE: Markers = > Erasers', 'nan', '0.833'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils', '2'})
# frozenset({'nan', '1 : { Pencils, Markers, Highlighters, Papers}', '2'})
# frozenset({'nan', '1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils'})
# frozenset({'RULE: Markers = > Erasers', 'nan', '1.19'})
# frozenset({'7 : {Markers, Erasers}', 'Card Holders', '2'})
# frozenset({'7 : {Markers, Erasers}', 'nan', '2'})
# frozenset({'Envelop', '2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', '2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', 'Card Holders', '2'})
# frozenset({'nan', 'Envelop', '2'})
# frozenset({'nan', 'Pencils', '2'})
# frozenset({'2 : {Markers, Erasers}', '6', 'Markers'})
# frozenset({'2 : {Markers, Erasers}', '6', 'nan'})
# frozenset({'2 : {Markers, Erasers}', 'Markers', 'nan'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', '3', 'Highlighters'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'nan', '3'})
# frozenset({'6 : {Envelop}', '3', 'Stapler Pins'})
# frozenset({'6 : {Envelop}', 'nan', '3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '3', 'Post-it'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'nan', '3'})
# frozenset({'nan', '3', 'Highlighters'})
# frozenset({'nan', '3', 'Post-it'})
# frozenset({'nan', '3', 'Stapler Pins'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'nan', 'Highlighters'})
# frozenset({'4', '4 : {Papers, Erasers, Cad Holders}', 'Papers'})
# frozenset({'4', 'nan', '4 : {Papers, Erasers, Cad Holders}'})
# frozenset({'4', 'nan', 'Papers'})
# frozenset({'4 : {Papers, Erasers, Cad Holders}', 'nan', 'Papers'})
# frozenset({'nan', '5', 'Markers,Erasers'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7', 'Erasers'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7', 'nan'})
# frozenset({'5 : {Markers, Post-it, Erasers}', 'nan', 'Erasers'})
# frozenset({'6', 'nan', 'Markers'})
# frozenset({'6 : {Envelop}', 'nan', 'Stapler Pins'})
# frozenset({'7', 'nan', 'Erasers'})
# frozenset({'7 : {Markers, Erasers}', 'nan', 'Card Holders'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'nan', 'Post-it'})
# frozenset({'nan', 'Envelop', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', 'Lift\nP(Erasers|Markers) / P( Erasers)', 'Confidence\n P(Erasers|Markers) = P(MarkersÇErasers)/P(Markers)'})
# frozenset({'Construct item-sets with items that satisfy minimum support', 'nan', 'Support\nP(MarkersÇErasers)'})
# frozenset({'Construct item-sets with items that satisfy minimum support', 'nan', '#Transactions in which\n the item is bought', 'Support\nP(MarkersÇErasers)'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils', '2', '0.2'})
# frozenset({'nan', '1 : { Pencils, Markers, Highlighters, Papers}', '2', '0.2'})
# frozenset({'nan', '1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils', '0.2'})
# frozenset({'7 : {Markers, Erasers}', 'Card Holders', '2', '0.2'})
# frozenset({'7 : {Markers, Erasers}', 'nan', '2', '0.2'})
# frozenset({'Envelop', '2', '0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', '2', '0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'nan', 'Card Holders', '2', '0.2'})
# frozenset({'nan', 'Envelop', '2', '0.2'})
# frozenset({'nan', 'Pencils', '2', '0.2'})
# frozenset({'7 : {Markers, Erasers}', 'nan', 'Card Holders', '0.2'})
# frozenset({'nan', 'Envelop', '0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'Highlighters', '3', '0.3'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'nan', '3', '0.3'})
# frozenset({'6 : {Envelop}', '3', '0.3', 'Stapler Pins'})
# frozenset({'6 : {Envelop}', 'nan', '3', '0.3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '3', '0.3', 'Post-it'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'nan', '3', '0.3'})
# frozenset({'Highlighters', 'nan', '3', '0.3'})
# frozenset({'nan', '3', '0.3', 'Post-it'})
# frozenset({'nan', '3', '0.3', 'Stapler Pins'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'nan', 'Highlighters', '0.3'})
# frozenset({'6 : {Envelop}', 'nan', 'Stapler Pins', '0.3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'nan', '0.3', 'Post-it'})
# frozenset({'4', '4 : {Papers, Erasers, Cad Holders}', '0.4', 'Papers'})
# frozenset({'4', 'nan', '4 : {Papers, Erasers, Cad Holders}', '0.4'})
# frozenset({'4', 'nan', '0.4', 'Papers'})
# frozenset({'4 : {Papers, Erasers, Cad Holders}', 'nan', '0.4', 'Papers'})
# frozenset({'nan', '5', '0.5', 'Markers,Erasers'})
# frozenset({'2 : {Markers, Erasers}', 'Markers', '6', '0.6'})
# frozenset({'2 : {Markers, Erasers}', '6', 'nan', '0.6'})
# frozenset({'2 : {Markers, Erasers}', 'Markers', 'nan', '0.6'})
# frozenset({'Markers', '6', 'nan', '0.6'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7', '0.7', 'Erasers'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7', '0.7', 'nan'})
# frozenset({'5 : {Markers, Post-it, Erasers}', 'nan', '0.7', 'Erasers'})
# frozenset({'7', '0.7', 'nan', 'Erasers'})
# frozenset({'RULE: Markers = > Erasers', 'nan', '1.19', '0.833'})
# frozenset({'nan', '1 : { Pencils, Markers, Highlighters, Papers}', 'Pencils', '2'})
# frozenset({'7 : {Markers, Erasers}', 'nan', 'Card Holders', '2'})
# frozenset({'nan', 'Envelop', '2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'2 : {Markers, Erasers}', '6', 'nan', 'Markers'})
# frozenset({'3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}', 'nan', '3', 'Highlighters'})
# frozenset({'6 : {Envelop}', 'nan', '3', 'Stapler Pins'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'nan', '3', 'Post-it'})
# frozenset({'4', 'nan', '4 : {Papers, Erasers, Cad Holders}', 'Papers'})
# frozenset({'5 : {Markers, Post-it, Erasers}', '7', 'nan', 'Erasers'})
# frozenset({'Pencils', 'nan', '0.2', '1 : { Pencils, Markers, Highlighters, Papers}', '2'})
# frozenset({'7 : {Markers, Erasers}', 'Card Holders', 'nan', '0.2', '2'})
# frozenset({'Envelop', 'nan', '0.2', '2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'Highlighters', 'nan', '0.3', '3', '3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}'})
# frozenset({'Stapler Pins', 'nan', '0.3', '6 : {Envelop}', '3'})
# frozenset({'nan', '0.3', '3', '8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', 'Post-it'})
# frozenset({'0.4', 'nan', '4', '4 : {Papers, Erasers, Cad Holders}', 'Papers'})
# frozenset({'6', '0.6', '2 : {Markers, Erasers}', 'Markers', 'nan'})
# frozenset({'5 : {Markers, Post-it, Erasers}', 'nan', 'Erasers', '7', '0.7'})

# %% [markdown]
# Generate the association rules for the given items from apriori algorithm.

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    # second index of the inner list
    print("Support: " + str(item[1]))
    # third index of the list located at 0th position
    # of the third index of the inner list
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("-----------------------------------------------------")
# Out:
# Rule: Construct item-sets with items that satisfy minimum support -> #Transactions in which
#  the item is bought
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: #Transactions in which
#  the item is bought -> Support
# P(MarkersÇErasers)
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 2 -> 0.2
# Support: 0.1875
# Confidence: 1.0
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 0.2 -> 9 : {StaplerPins, Post-it, Markers, Erasers}
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Card Holders -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Pencils -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 -> 0.3
# Support: 0.1875
# Confidence: 1.0
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Highlighters -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 0.3 -> Post-it
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Stapler Pins -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 4 -> 0.4
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 : {Papers, Erasers, Cad Holders} -> 0.4
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Papers -> 0.4
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 -> 0.5
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Markers,Erasers -> 0.5
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 0.6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 -> 0.6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Markers -> 0.6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 0.7 -> Erasers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 1.19 -> 0.833
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: RULE: Markers = > Erasers -> 0.833
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> 2
# Support: 0.0625
# Confidence: 1.0
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> Pencils
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: RULE: Markers = > Erasers -> 1.19
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 2 -> 9 : {StaplerPins, Post-it, Markers, Erasers}
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Card Holders -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Pencils -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> Markers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 -> Highlighters
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 -> Post-it
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 -> Stapler Pins
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> Highlighters
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> 4 : {Papers, Erasers, Cad Holders}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> Papers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 : {Papers, Erasers, Cad Holders} -> Papers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 -> Markers,Erasers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> Erasers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 -> Markers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> Stapler Pins
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 -> Erasers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> Card Holders
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> Post-it
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Envelop -> 9 : {StaplerPins, Post-it, Markers, Erasers}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Lift
# P(Erasers|Markers) / P( Erasers) -> Confidence
#  P(Erasers|Markers) = P(MarkersÇErasers)/P(Markers)
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Construct item-sets with items that satisfy minimum support -> Support
# P(MarkersÇErasers)
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Construct item-sets with items that satisfy minimum support -> #Transactions in which
#  the item is bought
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Construct item-sets with items that satisfy minimum support -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> #Transactions in which
#  the item is bought
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> Pencils
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 2 -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Card Holders -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Pencils -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 2
# Support: 0.1875
# Confidence: 1.0
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 0.2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Envelop
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Pencils
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Highlighters -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 3
# Support: 0.1875
# Confidence: 1.0
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> Highlighters
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> Stapler Pins
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Highlighters -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Stapler Pins
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 4 -> 4 : {Papers, Erasers, Cad Holders}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> 0.4
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 : {Papers, Erasers, Cad Holders} -> 0.4
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 : {Papers, Erasers, Cad Holders} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Papers -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 -> 0.5
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 5
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> Markers,Erasers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> Markers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Markers -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Markers -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: RULE: Markers = > Erasers -> 1.19
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 1.19
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: RULE: Markers = > Erasers -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> Pencils
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.0625
# Confidence: 1.0
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: RULE: Markers = > Erasers -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Envelop
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Pencils
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> Markers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> 4 : {Papers, Erasers, Cad Holders}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 : {Papers, Erasers, Cad Holders} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 5
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> Envelop
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> Lift
# P(Erasers|Markers) / P( Erasers)
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Construct item-sets with items that satisfy minimum support -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Construct item-sets with items that satisfy minimum support -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> Pencils
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 2
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Envelop
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Pencils
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Envelop
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> Highlighters
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Highlighters -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 4 -> 4 : {Papers, Erasers, Cad Holders}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 4 : {Papers, Erasers, Cad Holders} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 5
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> Markers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> Markers
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Markers -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 -> 0.7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: RULE: Markers = > Erasers -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: nan -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> Envelop
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 2 : {Markers, Erasers} -> 6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 6 : {Envelop} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers} -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> 7
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: Pencils -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> Card Holders
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Envelop -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Highlighters -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: Stapler Pins -> nan
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: nan -> 0.3
# Support: 0.0625
# Confidence: 0.3333333333333333
# Lift: 5.333333333333333
# -----------------------------------------------------
# Rule: 0.4 -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 6 -> 0.6
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
# Rule: 5 : {Markers, Post-it, Erasers} -> nan
# Support: 0.0625
# Confidence: 1.0
# Lift: 16.0
# -----------------------------------------------------
